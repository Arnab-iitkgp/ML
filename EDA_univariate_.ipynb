# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnab-iitkgp/ML/blob/main/EDA_univariate_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Video 20

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# CATEGORICAL DATA

# %%
#count plot for plotting bargraph
# sns.countplot(df,x="Pclass")
# sns.countplot(df,x="Sex")

#  another way
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# **Piechart**

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Numerical data** : whenever u use use numerical data try once by analysing making a histogram

# %%
#Histogram
plt.hist(df['Age'],bins =10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
#Distplot
sns.displot(df['Age'], kde= True) # tells about probability

# %%
#BOXPLOT
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# ![Screenshot 2026-01-29 195725.png](data:image/png;base64,...)

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
#practice on spotify data

# %%
df = pd.read_csv('/content/top_100_spotify_songs_2025.csv')

# %%
df.head()
# Out:
#    Rank Song_Title           Artist       Genre Release_Date  \
# 0     1     Song 1     Taylor Swift       Latin   2023-11-12
# 1     2     Song 2     Travis Scott         Pop   2024-10-20
# 2     3     Song 3       Ed Sheeran   Afrobeats   2023-04-23
# 3     4     Song 4         Doja Cat   Afrobeats   2023-05-21
# 4     5     Song 5  Imagine Dragons  Electronic   2023-03-29
#
#    Spotify_Streams_Millions  Popularity_Score  Duration_Seconds Explicit
# 0                   1686.11                79               282       No
# 1                    654.74                87               144      Yes
# 2                   1739.75                99               200      Yes
# 3                    924.50                66               282      Yes
# 4                    833.80                72               293      Yes

# %%
# sns.countplot(df,x='Genre')
df['Genre'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['Duration_Seconds'],bins=20)
# Out:
# (array([9., 4., 9., 7., 4., 3., 7., 4., 1., 7., 3., 5., 4., 6., 5., 6., 3.,
#         2., 7., 4.]),
#  array([120. , 128.8, 137.6, 146.4, 155.2, 164. , 172.8, 181.6, 190.4,
#         199.2, 208. , 216.8, 225.6, 234.4, 243.2, 252. , 260.8, 269.6,
#         278.4, 287.2, 296. ]),
#  <BarContainer object of 20 artists>)
